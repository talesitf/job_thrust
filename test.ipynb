# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama.llms import OllamaLLM

template = """Question: {question}"""

prompt = ChatPromptTemplate.from_template(template)

model = OllamaLLM(model="llama3")

chain = prompt | model

chain.invoke({"question": """Give me the responsabilities shown in this HTML: [<section><div class="sc-add46fb1-1 rSSXJ" data-testid="text-section"><h2 class="sc-c87ac0d4-0 gDozGp" data-testid="section-Descrição da vaga-title">Descrição da vaga</h2><div class="sc-add46fb1-3 iGcPoz"><p><span style="background-color:rgb(249, 249, 249);color:rgb(0, 0, 0)">Transformar dados brutos em informações para a tomada de decisões estratégicas da empresa, bem como interpretar grandes volumes de dados, padrões e tendências, fornecendo insights que impulsionem a eficiência operacional e o crescimento do negócio.</span></p></div></div><div class="sc-add46fb1-1 rSSXJ" data-testid="text-section"><h2 class="sc-c87ac0d4-0 gDozGp" data-testid="section-Responsabilidades e atribuições-title">Responsabilidades e atribuições</h2><div class="sc-add46fb1-3 iGcPoz"><p><ul><li class="ql-align-justify">Coletar, processar e analisar grandes conjuntos de dados provenientes de diversas fontes.</li><li class="ql-align-justify">Desenvolver e manter dashboards, relatórios e visualizações de dados para comunicar insights e apoiar a tomada de decisões.</li><li class="ql-align-justify">Colaborar com diferentes departamentos/projetos para entender suas necessidades de dados e fornecer soluções analíticas apropriadas.</li><li class="ql-align-justify">Identificar padrões e tendências nos dados para antecipar problemas e oportunidades de negócio.</li><li class="ql-align-justify">Assegurar a integridade e a qualidade dos dados, implementando processos de limpeza e validação.</li><li class="ql-align-justify">Utilizar ferramentas de Business Intelligence (BI) para otimizar processos e maximizar a eficiência.</li><li class="ql-align-justify">Utilizar linguagens de programação, bancos de dados e frameworks e bibliotecas para manipulação, análise e apresentação de dados.</li><li class="ql-align-justify">Manter-se atualizado com as melhores práticas e tendências em análise de dados e tecnologias emergentes.</li></ul><br/></p></div></div><div class="sc-add46fb1-1 rSSXJ" data-testid="text-section"><h2 class="sc-c87ac0d4-0 gDozGp" data-testid="section-Requisitos e qualificações-title">Requisitos e qualificações</h2><div class="sc-add46fb1-3 iGcPoz"><p><ul><li>Ensino superior completo em Engenharia, economia, ciência da computação ou áreas afins.</li><li>Experiência prévia em análise de dados</li><li><span style="color:rgb(13, 13, 13)">Ferramentas de análise de dados (ex: excel, SQL, Power BI, Tableau ou afins)</span></li></ul><br/></p></div></div><div class="sc-add46fb1-1 rSSXJ" data-testid="text-section"><h2 class="sc-c87ac0d4-0 gDozGp" data-testid="section-Informações adicionais-title">Informações adicionais</h2><div class="sc-add46fb1-3 iGcPoz"><p><ul><li>Vaga para Senai Poço</li><li>O processo seletivo terá como etapas: Prova específica e entrevista com gestor</li></ul><p>(Caso ocorra alguma alteração nas etapas, informaremos previamente)</p><ul><li>Para casos de aproveitamento em processos posteriores, este processo seletivo poderá ser utilizado no decorrer do ano de 2024, valendo-se que houve candidatos aptos.</li></ul><br/></p></div></div><div class="sc-add46fb1-1 rSSXJ" data-testid="text-section"><h2 class="sc-c87ac0d4-0 gDozGp" data-testid="section-Etapas do processo-title">Etapas do processo</h2><ol class="sc-97f6c339-0 wTJDe" data-testid="job-steps-list"><li><span class="sc-dfd42894-0 bzQMFp">Etapa 1: Cadastro</span><span aria-hidden="true" class="counter">1</span><span aria-hidden="true">Cadastro</span></li><li><span class="sc-dfd42894-0 bzQMFp">Etapa 2: Prova específica </span><span aria-hidden="true" class="counter">2</span><span aria-hidden="true">Prova específica </span></li><li><span class="sc-dfd42894-0 bzQMFp">Etapa 3: Entrevista com Rh e Gestor</span><span aria-hidden="true" class="counter">3</span><span aria-hidden="true">Entrevista com Rh e Gestor</span></li><li><span class="sc-dfd42894-0 bzQMFp">Etapa 4: Contratação</span><span aria-hidden="true" class="counter">4</span><span aria-hidden="true">Contratação</span></li></ol></div><div class="sc-add46fb1-1 rSSXJ" data-testid="text-section"><h2 class="sc-c87ac0d4-0 gDozGp" data-testid="section-Faça parte do Sesi Senai Alagoas e ajude a transformar a vida das pessoas e das indústrias-title">Faça parte do Sesi Senai Alagoas e ajude a transformar a vida das pessoas e das indústrias</h2><div class="sc-add46fb1-3 iGcPoz"><p class="ql-align-justify">O <strong style="color:rgb(0, 0, 245)">Sesi (Serviço Social da Indústria)</strong> e o<strong style="color:rgb(0, 0, 245)"> Senai (Serviço Nacional de Aprendizagem Industrial)</strong> fazem parte do <strong style="color:rgb(0, 0, 245)">Sistema Fiea</strong>, que é integrante de um sistema nacional, constituído por 27 federações estaduais e liderado pela Confederação Nacional da Indústria, CNI.</p><p class="ql-align-justify">Somos uma empresa que há décadas trabalha mudando vidas e construindo histórias de sucesso! Nossas unidades estão localizadas em Maceió/AL e em Arapiraca/AL, mas o impacto do nosso trabalho atravessa fronteiras!</p><p class="ql-align-justify">Em nosso time, as possibilidades de trabalho são inúmeras!</p><p class="ql-align-justify">Você pode, por exemplo, fazer parte da equipe de segurança e saúde do Sesi; ou atuar na área de Educação básica e profissionalizante do Sesi Senai; se preferir, pode trabalhar com Tecnologia e Inovação; ou até mesmo oferecendo nossas soluções para empresas.</p><br/><p class="ql-align-justify">Se você preza pelo <strong style="color:rgb(0, 0, 245)">respeito</strong>, a <strong style="color:rgb(0, 0, 245)">verdade</strong>, a <strong style="color:rgb(0, 0, 245)">transparência</strong> e o <strong style="color:rgb(0, 0, 245)">zelo pelo cliente</strong>, chegou ao lugar certo! Somos constantemente <strong style="color:rgb(0, 0, 245)">movidos por resultados</strong>. Para isso devemos atuar com <strong style="color:rgb(0, 0, 245)">agilidade</strong><strong> </strong><strong style="color:rgb(0, 0, 245)">e simplicidade</strong>, buscando <strong style="color:rgb(0, 0, 245)">inovar</strong> cada vez mais a nossa <strong style="color:rgb(0, 0, 245)">ação</strong>. Desta forma, estaremos sempre<strong> </strong><strong style="color:rgb(0, 0, 245)">junto em evolução</strong><strong>.</strong></p><p class="ql-align-justify"><br/></p><p class="ql-align-justify"><span style="color:rgb(0, 0, 0)">Visite o nosso site e saiba mais sobre nós!</span></p><p class="ql-align-justify"><br/></p></div></div></section>]?"""})
# Out:
# "Based on the provided HTML code, I'll identify the responsibilities shown:\n\n**No specific responsibilities are explicitly mentioned in this HTML code.**\n\nThe code appears to be a combination of a navigation menu (with `<li>` elements) and a section with a heading and paragraphs of text. The text describes the organization Sesi Senai Alagoas, its mission, values, and opportunities for work.\n\nIf you're looking for specific responsibilities related to job openings or career paths at Sesi Senai Alagoas, I'd suggest searching for additional information on their website or other recruitment sources."

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    model="llama3",
    temperature=0,
)

# %%
from langchain_core.messages import AIMessage

messages = [
    (
        "system",
        "You are a helpful assistant that translates English to French. Translate the user sentence.",
    ),
    ("human", "I love programming."),
]
ai_msg = llm.invoke(messages)
ai_msg
# Out:
# AIMessage(content='Je adore le programmation.\n\n(Note: "programmation" is the feminine form of the noun in French, but if you want to use the masculine form, it would be "le programme" instead.)', additional_kwargs={}, response_metadata={'model': 'llama3', 'created_at': '2024-11-19T18:53:54.396532296Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 708884281, 'load_duration': 24597981, 'prompt_eval_count': 35, 'prompt_eval_duration': 39013000, 'eval_count': 43, 'eval_duration': 514987000}, id='run-2a348f56-e892-4bca-b038-d3503ef1e16a-0', usage_metadata={'input_tokens': 35, 'output_tokens': 43, 'total_tokens': 78})

# %%
from langchain_ollama import OllamaEmbeddings

embeddings = OllamaEmbeddings(model="llama3")

embeddings.embed_query("Hello, world!")
# Out:
# [-0.009181463,
#  -0.021038087,
#  0.007825147,
#  0.0051331553,
#  -0.023562439,
#  0.008347341,
#  -0.006832074,
#  0.022928229,
#  0.008052959,
#  0.00651022,
#  -0.019310992,
#  0.009440784,
#  -0.0046885367,
#  -0.011432868,
#  -0.00022142631,
#  0.0045809313,
#  -0.020257086,
#  -0.00801534,
#  -0.021322183,
#  0.012199889,
#  -0.017622484,
#  -0.005181827,
#  0.006589905,
#  0.019143393,
#  -0.011373231,
#  0.0052054254,
#  0.001547026,
#  -0.023696136,
#  0.005901601,
#  -0.009165447,
#  0.0012966619,
#  0.011549557,
#  -0.012430675,
#  0.00016549573,
#  0.06819467,
#  -0.0036753272,
#  0.002113992,
#  -0.00660513,
#  0.009796909,
#  0.021576349,
#  0.0036974838,
#  0.0024219786,
#  0.0011329516,
#  -0.0055736583,
#  0.013013387,
#  0.0021615662,
#  0.019235801,
#  0.006800382,
#  0.024544075,
#  -0.0057810023,
#  0.006874773,
#  -0.003119093,
#  -0.016048077,
#  0.012500302,
#  -0.0027714565,
#  -0.0021295846,
#  -0.00027524945,
#  -0.0006696436,
#  -0.0016365885,
# ...
